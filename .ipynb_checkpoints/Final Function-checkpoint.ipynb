# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import statsmodels.tools
from sklearn.preprocessing import OneHotEncoder
import seaborn as sns
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
#ridge
from sklearn.linear_model import Ridge

# %%
def predictor4():

    # variable 'le' is a dataframe of the whole dataset
    # %store -r le

    minmax = MinMaxScaler()
    minmax.fit(le[['Under_five_deaths', 'Adult_mortality', 'BMI', 'Hepatitis_B', 'Polio']])

    minmax1 = MinMaxScaler()
    minmax1.fit(le[['Under_five_deaths', 'Adult_mortality']])

    ethical_y_n = 'y'
    while ethical_y_n == 'y' or 'n':
        try:
            ethical_y_n = str(input('Do you want to use private data?'))
            break
        except:
            print('Wrong datatype input')

    if ethical_y_n == 'y':
        feature = [0]*12
        i = 0
        while i < len(feature):
            if i == 0:
                while True:
                    try:
                        year = int(input('What is the year?'))
                        feature[0] = year - 2000
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 1:
                while True:
                    try:
                        feature[i] = float(input('What is the under 5 deaths?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 2:
                while True:
                    try:
                        feature[i] = float(input('What is the adult mortality?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 3:
                while True:
                    try:
                        feature[i] = float(input('What is the alcohol consumption?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 4:
                while True:
                    try:
                        feature[i] = float(input('What is the BMI'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 5:
                while True:
                    try:
                        feature[i] = int(input('What is the polio percentage?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 6:
                while True:
                    try:
                        feature[i] = int(input('What is the hepatitis_b percentage?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 7:
                while True:
                    try:
                        feature[i] = float(input('What is the thinness 10-19?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 8:
                while True:
                    try:
                        feature[i] = float(input('How many incidents of HIV are there?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 9:
                while True:
                    try:
                        feature[i] = int(input('Is the economy status developed?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 10:
                while True:
                    try:
                        feature[i] = float(input('What is the years of schooling?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 11:
                while True:
                    try:
                        GDP = float(input('What is the GDP per capita?'))
                        feature[i] = np.log(GDP)
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')

        columns1 = ['Under_five_deaths', 'Adult_mortality', 'BMI', 'Hepatitis_B', 'Polio']
        features = [feature[1], feature[2], feature[4], feature[6], feature[5]]

        df = pd.DataFrame([features], columns=columns1)
        df[columns1] = minmax.transform(df[columns1])

        sc_u5 = df.loc[0]['Under_five_deaths']
        sc_am = df.loc[0]['Adult_mortality']
        sc_bmi = df.loc[0]['BMI']
        sc_hb = df.loc[0]['Hepatitis_B']
        sc_p = df.loc[0]['Polio']

        return (73.3236 + feature[0]*0.0299 + sc_u5*-16.8442 + sc_am*-30.8633 +
                feature[3]*0.0498 + sc_bmi*-2.4692 + sc_p*1.1625 + sc_hb*-0.8044 +
                feature[7]*-0.0482 + feature[8]*0.0577 + feature[9]*0.8520 +
                feature[10]*0.0775 + feature[11]*0.5957)

    elif ethical_y_n == 'n':
        feature = [0]*7
        i = 0
        while i < len(feature):
            if i == 0:
                while True:
                    try:
                        year = int(input('What is the year?'))
                        feature[0] = year - 2000
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 1:
                while True:
                    try:
                        feature[i] = float(input('What is the under 5 deaths?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 2:
                while True:
                    try:
                        feature[i] = float(input('What is the adult mortality?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 3:
                while True:
                    try:
                        feature[i] = float(input('What is the alcohol consumption?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 4:
                while True:
                    try:
                        feature[i] = float(input('What is the years of schooling?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 5:
                while True:
                    try:
                        feature[i] = int(input('Is the economy status developed?'))
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')
            elif i == 6:
                while True:
                    try:
                        GDP = float(input('What is the GDP per capita?'))
                        feature[i] = np.log(GDP)
                        i += 1
                        break
                    except:
                        print('Wrong datatype input')

        columns2 = ['Under_five_deaths', 'Adult_mortality']
        features = [feature[1], feature[2]]

        df = pd.DataFrame([features], columns=columns2)
        df[columns2] = minmax1.transform(df[columns2])

        sc_u5 = df.loc[0]['Under_five_deaths']
        sc_am = df.loc[0]['Adult_mortality']

        return (73.0590 + feature[0]*0.0228 + sc_u5*-16.9706 + sc_am*-29.9728 +
                feature[3]*0.0604 + feature[4]*0.0526 + feature[5]*1.2061 +
                feature[6]*0.5146)

# %%
predictor4()
# Out:
# Do you want to use private data? n
# What is the year? 2015
# What is the under 5 deaths? 13
# What is the adult mortality? 182.4
# What is the alcohol consumption? 1.32
# What is the years of schooling? 7.8
# Is the economy status developed? 1
# What is the GDP per capita? 11006
# 73.11957980301378
