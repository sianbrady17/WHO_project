# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import statsmodels.tools
from sklearn.preprocessing import OneHotEncoder
import seaborn as sns
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
#ridge
from sklearn.linear_model import Ridge

# %%
def predictor6():

    # variable 'le' is a dataframe of the whole dataset
    # %store -r le
    # %store -r X_train_fe
    # %store -r model

    minmax = MinMaxScaler()
    # minmax.fit(le[['Under_five_deaths', 'Adult_mortality', 'BMI', 'Hepatitis_B', 'Polio']])
    minmax.fit(X_train_fe[['Under_five_deaths', 'Adult_mortality', 'BMI', 'Hepatitis_B', 'Polio']])

    minmax1 = MinMaxScaler()
    # minmax1.fit(le[['Under_five_deaths', 'Adult_mortality']])
    minmax1.fit(X_train_fe[['Under_five_deaths', 'Adult_mortality']])

    ethical_y_n = 'y'
    while ethical_y_n == 'y' or 'n':
        try:
            ethical_y_n = str(input('Do you want to use private data?'))
            break
        except:
            print('Wrong datatype input')

    if ethical_y_n == 'y':
        while True:
            try:
                year = int(input('What is the year?'))
                year_m = year - 2000
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                u5 = float(input('What is the under 5 deaths?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                am = float(input('What is the adult mortality?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                ac = float(input('What is the alcohol consumption?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                bmi = float(input('What is the BMI'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                polio = int(input('What is the polio percentage?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                hep_b = int(input('What is the hepatitis_b percentage?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                thin = float(input('What is the thinness 10-19?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                hiv = float(input('How many incidents of HIV are there?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                ecd = int(input('Is the economy status developed?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                sch = float(input('What is the years of schooling?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                GDP = float(input('What is the GDP per capita?'))
                gdp_l = np.log(GDP)
                break
            except:
                print('Wrong datatype input')

        columns1 = ['Under_five_deaths', 'Adult_mortality', 'BMI', 'Hepatitis_B', 'Polio']
        features = [u5, am, bmi, hep_b, polio]

        df = pd.DataFrame([features], columns=columns1)
        df[columns1] = minmax.transform(df[columns1])

        sc_u5 = df.loc[0]['Under_five_deaths']
        sc_am = df.loc[0]['Adult_mortality']
        sc_bmi = df.loc[0]['BMI']
        sc_hb = df.loc[0]['Hepatitis_B']
        sc_p = df.loc[0]['Polio']

        return (73.3236 + year_m*0.0299 + sc_u5*-16.8442 + sc_am*-30.8633 +
                ac*0.0498 + sc_bmi*-2.4692 + sc_p*1.1625 + sc_hb*-0.8044 +
                thin*-0.0482 + hiv*0.0577 + ecd*0.8520 +
                sch*0.0775 + gdp_l*0.5957)

    elif ethical_y_n == 'n':
        while True:
            try:
                year_m = int(input('What is the year?'))
                # year_m = year - 2000
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                u5 = float(input('What is the under 5 deaths?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                am = float(input('What is the adult mortality?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                ac = float(input('What is the alcohol consumption?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                sch = float(input('What is the years of schooling?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                ecd = int(input('Is the economy status developed?'))
                break
            except:
                print('Wrong datatype input')
        while True:
            try:
                GDP = float(input('What is the GDP per capita?'))
                gdp_l = np.log(GDP)
                break
            except:
                print('Wrong datatype input')

        columns2 = ['Adult_mortality', 'Economy_status_Developed', 'GDP_per_capita_log', 'Under_five_deaths', 'Schooling', 'Year', 'Alcohol_consumption']
        features = [am, ecd, gdp_l, u5, sch, year_m, ac]

        # %store -r minmax2

        df = pd.DataFrame([features], columns=columns2)
        df[columns2] = minmax2.transform(df[columns2])

        sc_u5 = df.loc[0]['Under_five_deaths']
        sc_am = df.loc[0]['Adult_mortality']
        ecd = df.loc[0]['Economy_status_Developed']
        gdp_l = df.loc[0]['GDP_per_capita_log']
        sch = df.loc[0]['Schooling']
        year_m = df.loc[0]['Year']
        ac = df.loc[0]['Alcohol_consumption']

        input_features = pd.DataFrame([[1.0, sc_am, ecd, gdp_l, sc_u5, sch, year_m, ac]],
                                      columns = ['const', 'Adult_mortality', 'Economy_status_Developed', 'GDP_per_capita_log', 'Under_five_deaths', 'Schooling', 'Year', 'Alcohol_consumption'])
        
        # input_features = sm.add_constant(input_features)

        # return (75.6883 + year_m*0.0228 + sc_u5*-16.9706 + sc_am*-29.9728 +
        #         ac*0.0604 + sch*0.0526 + ecd*1.2061 +
        #         gdp_l*0.5146)

        # %store -r model

        return model.predict(input_features)

        # return input_features

# %%
predictor6()
# Out:
# Do you want to use private data? n
# What is the year? 2015
# What is the under 5 deaths? 13
# What is the adult mortality? 105.824
# What is the alcohol consumption? 1.32
# What is the years of schooling? 7.8
# Is the economy status developed? 1
# What is the GDP per capita? 11006
# 0    76.484393
# dtype: float64
